# %% [markdown]
# #Syringe Pump Controller

# %%
import ipywidgets as widgets
from IPython.display import display, clear_output
import gui_setup
# Out:
# 🔍 Starting search for serial pumps...
# Checking ports: ['COM11', 'COM12', 'COM13']
# Trying port COM11...
# ✔ Port COM11 is available
# Trying port COM12...
# ✔ Port COM12 is available
# Trying port COM13...
# ✘ Port COM13 failed: could not open port 'COM13': FileNotFoundError(2, 'The system cannot find the file specified.', None, 2)
# Final result: ['COM11', 'COM12']
#  - Ports found: ['COM11', 'COM12']
#
# 🛠️ Trying port COM11 with address 0...
#   🔄 Sending '?76' to COM11...
#   ✅ Config response: b'9600|100K|484|6dist|AUTO'
#   🔄 Sending '&' to COM11...
#   ✅ Firmware version: b'30159774 C'
#   🎉 Device found on COM11 with address 0
#
# 🛠️ Trying port COM12 with address 0...
#   🔄 Sending '?76' to COM12...
#   ⏱️ Timeout waiting for response on COM12. Skipping.
#
# ✅ Search complete. Devices found: 1
# ...
